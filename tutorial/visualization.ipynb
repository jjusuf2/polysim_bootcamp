# %% [markdown]
# # Visualization
#
# This notebook shows you how to visualize a polymer conformation in an iPython notebook (VSCode/Jupyter) using the `py3Dmol` package.

# %%
# setup
import numpy as np
import py3Dmol  # for visualizing the polymer
from polychrom.hdf5_format import list_URIs, load_URI  # for opening simulation output files

# %% [markdown]
# ## Load the data

# %%
# First, use `list_URIs` to create a list of the file paths of the saved blocks:

output_folder = '/mnt/md1/jjusuf/polysim/outputs/trajectory0003_npoly70000_nchr1_dens0.3_life75000_sep240_vlef0.0025_dt40_stallsites0.05-0.6_lifeboost4_ntypes2'
files = list_URIs(output_folder)

print(f'{len(files)} saved blocks found')
# Out:
# 360000 saved blocks found

# %%
# Then, open one of the conformations

save_block_num = 56711
uri = load_URI(files[save_block_num])
xyz = uri['pos']

print(xyz)
print(f'shape: {xyz.shape}')

# It is an (N, 3) array of xyz positions of all N monomers
# Out:
# [[ -6.077  10.363  -7.298]
#  [ -5.328  10.14   -7.987]
#  [ -4.389  10.626  -8.05 ]
#  ...
#  [ -3.865 -16.221  -4.126]
#  [ -4.766 -16.142  -4.35 ]
#  [ -4.394 -16.575  -5.356]]
# shape: (70000, 3)

# %% [markdown]
# ## Visualize the polymer

# %%
# Take a subset of the polymer (first 100 monomers)
xyz_subset = xyz[:100,:]

# %%
# Sphere model
# Here we draw a sphere for each monomer

view = py3Dmol.view()

for i in range(len(xyz_subset)):
    pos = xyz_subset[i,:]
    view.addSphere({
        "center": {"x": float(pos[0]), "y": float(pos[1]), "z": float(pos[2])},
        "radius": 0.5,
        "color": "#dddddd"
    })

view.setBackgroundColor('white')
view.zoomTo()
view.show()
# Out:
# <div id="3dmolviewer_17870850347652326"  style="position: relative; width: 640px; height: 480px;">
#         <p id="3dmolwarning_17870850347652326" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.5/build/3Dmol-min.js');
# }
#
# var viewer_17870850347652326 = null;
# var warn = document.getElementById("3dmolwarning_17870850347652326");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17870850347652326 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17870850347652326"),{backgroundColor:"white"});
# viewer_17870850347652326.zoomTo();
# 	viewer_17870850347652326.addSphere({"center": {"x": -6.672999858856201, "y": 9.954000473022461, "z": -3.7339999675750732}, "radius": 0.5, "color": "#dddddd"});
# 	viewer_17870850347652326.addSphere({"center": {"x": -6.019999980926514, "y": 10.168999671936035, "z": -4.466000080108643}, "radius": 0.5, "color": "#dddddd"});
# 	viewer_17870850347652326.addSphere({"center": {"x": -6.269000053405762, "y": 9.14900016784668, "z": -4.794000148773193}, "radius": 0.5, "color": "#dddddd"});
# 	viewer_17870850347652326.addSphere({"center": {"x": -5.813000202178955, "y": 8.192999839782715, "z": -4.698999881744385}, "radius": 0.5, "color": "#dddddd"});
# 	viewer_17870850347652326.addSphere({"center": {"x": -5.283999919891357, "y": 8.01200008392334, "z": -4.146999835968018}, "radius": 0.5, "color": "#dddddd"});
# 	viewer_17870850347652326.addSphere({"center": {"x": -4.564000129699707, "y": 8.33899974822998, "z": -4.678999900817871}, "radius": 0.5, "color": "#dddddd"});
# 	viewer_17870850347652326.addSphere({"center": {"x": -3.9230000972747803, "y": 7.886000156402588, "z": -4.1579999923706055}, "radius": 0.5, "color": "#dddddd"});
# 	viewer_17870850347652326.addSphere({"center": {"x": -4.36899995803833, "y": 7.158999919891357, "z": -4.7870001792907715}, "radius": 0.5, "color": "#dddddd"});
# 	viewer_17870850347652326.addSphere({"center": {"x": -4.11299991607666, "y": 7.333000183105469, "z": -5.710999965667725}, "radius": 0.5, "color": "#dddddd"});
# 	viewer_17870850347652326.addSphere({"center": {"x": -3.375999927520752, "y": 7.515999794006348, "z": -6.301000118255615}, "radius": 0.5, "color": "#dddddd"});
# 	viewer_17870850347652326.addSphere({"center": {"x": -2.50600004196167, "y": 6.894000053405762, "z": -6.050000190734863}, "radius": 0.5, "color": "#dddddd"});
# 	viewer_17870850347652326.addSphere({"center": {"x": -3.322000026702881, "y": 6.4029998779296875, "z": -6.360000133514404}, "radius": 0.5, "color": "#dddddd"});
# 	viewer_17870850347652326.addSphere({"center": {"x": -3.687000036239624, "y": 5.453000068664551, "z": -6.169000148773193}, "radius": 0.5, "color": "#dddddd"});
# 	viewer_17870850347652326.addSphere({"center": {"x": -4.039999961853027, "y": 5.2210001945495605, "z": -5.197000026702881}, "radius": 0.5, "color": "#dddddd"});
# 	viewer_17870850347652326.addSphere({"center": {"x": -3.1740000247955322, "y": 5.638999938964844, "z": -4.802000045776367}, "radius": 0.5, "color": "#dddddd"});
# 	viewer_17870850347652326.addSphere({"center": {"x": -2.9149999618530273, "y": 5.4629998207092285, "z": -3.744999885559082}, "radius": 0.5, "color": "#dddddd"});
# 	viewer_17870850347652326.addSphere({"center": {"x": -2.0840001106262207, "y": 5.066999912261963, "z": -4.297999858856201}, "radius": 0.5, "color": "#dddddd"});
# 	viewer_17870850347652326.addSphere({"center": {"x": -1.3420000076293945, "y": 5.052000045776367, "z": -5.065999984741211}, "radius": 0.5, "color": "#dddddd"});
# 	viewer_17870850347652326.addSphere({"center": {"x": -0.6959999799728394, "y": 4.883999824523926, "z": -4.4710001945495605}, "radius": 0.5, "color": "#dddddd"});
# 	viewer_17870850347652326.addSphere({"center": {"x": -0.46399998664855957, "y": 4.039999961853027, "z": -4.841000080108643}, "radius": 0.5, "color": "#dddddd"});
# 	viewer_17870850347652326.addSphere({"center": {"x": -0.17399999499320984, "y": 3.7119998931884766, "z": -5.796999931335449}, "radius": 0.5, "color": "#dddddd"});
# 	viewer_17870850347652326.addSphere({"center": {"x": -0.7590000033378601, "y": 4.298999786376953, "z": -6.428999900817871}, "radius": 0.5, "color": "#dddddd"});
# 	viewer_17870850347652326.addSphere({"center": {"x": -0.6959999799728394, "y": 5.296000003814697, "z": -6.828000068664551}, "radius": 0.5, "color": "#dddddd"});
# 	viewer_17870850347652326.addSphere({"center": {"x": -0.06800000369548798, "y": 4.906000137329102, "z": -7.63700008392334}, "radius": 0.5, "color": "#dddddd"});
# 	viewer_17870850347652326.addSphere({"center": {"x": -0.5870000123977661, "y": 4.039000034332275, "z": -7.690000057220459}, "radius": 0.5, "color": "#dddddd"});
# 	viewer_17870850347652326.addSphere({"center": {"x": -0.13300000131130219, "y": 4.276000022888184, "z": -8.586000442504883}, "radius": 0.5, "color": "#dddddd"});
# 	viewer_17870850347652326.addSphere({"center": {"x": 0.09099999815225601, "y": 3.5380001068115234, "z": -9.0600004196167}, "radius": 0.5, "color": "#dddddd"});
# 	viewer_17870850347652326.addSphere({"center": {"x": 0.6909999847412109, "y": 3.0220000743865967, "z": -9.656999588012695}, "radius": 0.5, "color": "#dddddd"});
# 	viewer_17870850347652326.addSphere({"center": {"x": 1.0069999694824219, "y": 2.1480000019073486, "z": -9.604999542236328}, "radius": 0.5, "color": "#dddddd"});
# 	viewer_17870850347652326.addSphere({"center": {"x": 1.6109999418258667, "y": 2.194999933242798, "z": -10.510000228881836}, "radius": 0.5, "color": "#dddddd"});
# 	viewer_17870850347652326.addSphere({"center": {"x": 1.777999997138977, "y": 3.1989998817443848, "z": -10.706999778747559}, "radius": 0.5, "color": "#dddddd"});
# 	viewer_17870850347652326.addSphere({"center": {"x": 1.9049999713897705, "y": 4.2170000076293945, "z": -10.569999694824219}, "radius": 0.5, "color": "#dddddd"});
# 	viewer_17870850347652326.addSphere({"center": {"x": 1.7910000085830688, "y": 4.813000202178955, "z": -11.395000457763672}, "radius": 0.5, "color": "#dddddd"});
# 	viewer_17870850347652326.addSphere({"center": {"x": 2.1630001068115234, "y": 5.328999996185303, "z": -10.885000228881836}, "radius": 0.5, "color": "#dddddd"});
# 	viewer_17870850347652326.addSphere({"center": {"x": 2.444000005722046, "y": 6.191999912261963, "z": -10.460000038146973}, "radius": 0.5, "color": "#dddddd"});
# 	viewer_17870850347652326.addSphere({"center": {"x": 3.244999885559082, "y": 6.757999897003174, "z": -10.36400032043457}, "radius": 0.5, "color": "#dddddd"});
# 	viewer_17870850347652326.addSphere({"center": {"x": 3.2139999866485596, "y": 7.013000011444092, "z": -9.501999855041504}, "radius": 0.5, "color": "#dddddd"});
# 	viewer_17870850347652326.addSphere({"center": {"x": 4.10099983215332, "y": 7.5279998779296875, "z": -9.343000411987305}, "radius": 0.5, "color": "#dddddd"});
# 	viewer_17870850347652326.addSphere({"center": {"x": 4.438000202178955, "y": 6.729000091552734, "z": -8.644000053405762}, "radius": 0.5, "color": "#dddddd"});
# 	viewer_17870850347652326.addSphere({"center": {"x": 5.190000057220459, "y": 6.789000034332275, "z": -8.086999893188477}, "radius": 0.5, "color": "#dddddd"});
# 	viewer_17870850347652326.addSphere({"center": {"x":

# %%
# Stick model
# Here we draw sticks between every pair of adjacent monomers

view = py3Dmol.view()

for i in range(len(xyz_subset)-1):
    pos1 = xyz_subset[i,:]
    pos2 = xyz_subset[i+1,:]
    view.addCylinder({
        "start": {"x": float(pos1[0]), "y": float(pos1[1]), "z": float(pos1[2])},
        "end":   {"x": float(pos2[0]), "y": float(pos2[1]), "z": float(pos2[2])},
        "radius": 0.4,
        "fromCap": 2, "toCap": 2,
        "color": "#dddddd"
    })

view.setBackgroundColor('white')
view.zoomTo()
view.show()
# Out:
# <div id="3dmolviewer_17867313135014665"  style="position: relative; width: 640px; height: 480px;">
#         <p id="3dmolwarning_17867313135014665" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.5/build/3Dmol-min.js');
# }
#
# var viewer_17867313135014665 = null;
# var warn = document.getElementById("3dmolwarning_17867313135014665");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17867313135014665 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17867313135014665"),{backgroundColor:"white"});
# viewer_17867313135014665.zoomTo();
# 	viewer_17867313135014665.addCylinder({"start": {"x": -6.077000141143799, "y": 10.36299991607666, "z": -7.297999858856201}, "end": {"x": -5.328000068664551, "y": 10.140000343322754, "z": -7.986999988555908}, "radius": 0.4, "fromCap": 2, "toCap": 2, "color": "#dddddd"});
# 	viewer_17867313135014665.addCylinder({"start": {"x": -5.328000068664551, "y": 10.140000343322754, "z": -7.986999988555908}, "end": {"x": -4.388999938964844, "y": 10.62600040435791, "z": -8.050000190734863}, "radius": 0.4, "fromCap": 2, "toCap": 2, "color": "#dddddd"});
# 	viewer_17867313135014665.addCylinder({"start": {"x": -4.388999938964844, "y": 10.62600040435791, "z": -8.050000190734863}, "end": {"x": -4.658999919891357, "y": 10.734999656677246, "z": -7.111000061035156}, "radius": 0.4, "fromCap": 2, "toCap": 2, "color": "#dddddd"});
# 	viewer_17867313135014665.addCylinder({"start": {"x": -4.658999919891357, "y": 10.734999656677246, "z": -7.111000061035156}, "end": {"x": -4.3460001945495605, "y": 10.5649995803833, "z": -6.271999835968018}, "radius": 0.4, "fromCap": 2, "toCap": 2, "color": "#dddddd"});
# 	viewer_17867313135014665.addCylinder({"start": {"x": -4.3460001945495605, "y": 10.5649995803833, "z": -6.271999835968018}, "end": {"x": -4.460000038146973, "y": 9.786999702453613, "z": -6.859000205993652}, "radius": 0.4, "fromCap": 2, "toCap": 2, "color": "#dddddd"});
# 	viewer_17867313135014665.addCylinder({"start": {"x": -4.460000038146973, "y": 9.786999702453613, "z": -6.859000205993652}, "end": {"x": -3.513000011444092, "y": 9.70300006866455, "z": -7.263000011444092}, "radius": 0.4, "fromCap": 2, "toCap": 2, "color": "#dddddd"});
# 	viewer_17867313135014665.addCylinder({"start": {"x": -3
for i in range(len(xyz_subset)):
    pos = xyz_subset[i,:]
    monomer_index = indices[i]

    if (monomer_index % region_size) in sticky_monomers:
        color = "#1eabec"
        alpha = 1
    elif (monomer_index % region_size) in ctcf_sites:
        color = "#c71a34"
        alpha = 1
    else:
        color = "#dddddd"  # default color
        alpha = 0.75         # make them translucent

    view.addSphere({
        "center": {"x": float(pos[0]), "y": float(pos[1]), "z": float(pos[2])},
        "radius": 0.5,
        "color": color,
        "alpha": alpha
    })

view.setBackgroundColor('white')
view.zoomTo()
view.show()
# Out:
# <div id="3dmolviewer_17871167741321266"  style="position: relative; width: 640px; height: 480px;">
#         <p id="3dmolwarning_17871167741321266" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.5/build/3Dmol-min.js');
# }
#
# var viewer_17871167741321266 = null;
# var warn = document.getElementById("3dmolwarning_17871167741321266");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17871167741321266 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17871167741321266"),{backgroundColor:"white"});
# viewer_17871167741321266.zoomTo();
# 	viewer_17871167741321266.addSphere({"center": {"x": -13.579999923706055, "y": 12.388999938964844, "z": -16.631999969482422}, "radius": 0.5, "color": "#dddddd", "alpha": 0.75});
# 	viewer_17871167741321266.addSphere({"center": {"x": -13.361000061035156, "y": 12.881999969482422, "z": -17.606000900268555}, "radius": 0.5, "color": "#dddddd", "alpha": 0.75});
# 	viewer_17871167741321266.addSphere({"center": {"x": -13.618000030517578, "y": 13.767000198364258, "z": -18.072999954223633}, "radius": 0.5, "color": "#dddddd", "alpha": 0.75});
# 	viewer_17871167741321266.addSphere({"center": {"x": -14.244000434875488, "y": 13.95300006866455, "z": -18.80299949645996}, "radius": 0.5, "color": "#dddddd", "alpha": 0.75});
# 	viewer_17871167741321266.addSphere({"center": {"x": -13.590999603271484, "y": 13.73900032043457, "z": -19.701000213623047}, "radius": 0.5, "color": "#dddddd", "alpha": 0.75});
# 	viewer_17871167741321266.addSphere({"center": {"x": -14.008000373840332, "y": 14.664999961853027, "z": -20.073999404907227}, "radius": 0.5, "color": "#dddddd", "alpha": 0.75});
# 	viewer_17871167741321266.addSphere({"center": {"x": -14.371000289916992, "y": 15.612000465393066, "z": -20.25200080871582}, "radius": 0.5, "color": "#dddddd", "alpha": 0.75});
# 	viewer_17871167741321266.addSphere({"center": {"x": -14.800999641418457, "y": 16.270999908447266, "z": -19.829999923706055}, "radius": 0.5, "color": "#dddddd", "alpha": 0.75});
# 	viewer_17871167741321266.addSphere({"center": {"x": -15.527000427246094, "y": 16.624000549316406, "z": -19.47599983215332}, "radius": 0.5, "color": "#dddddd", "alpha": 0.75});
# 	viewer_17871167741321266.addSphere({"center": {"x": -16.23699951171875, "y": 17.202999114990234, "z": -19.67300033569336}, "radius": 0.5, "color": "#dddddd", "alpha": 0.75});
# 	viewer_17871167741321266.addSphere({"center": {"x": -16.950000762939453, "y": 17.541000366210938, "z": -20.094999313354492}, "radius": 0.5, "color": "#dddddd", "alpha": 0.75});
# 	viewer_17871167741321266.addSphere({"center": {"x": -17.31599998474121, "y": 16.604999542236328, "z": -20.39900016784668}, "radius": 0.5, "color": "#dddddd", "alpha": 0.75});
# 	viewer_17871167741321266.addSphere({"center": {"x": -16.90399932861328, "y": 17.274999618530273, "z": -21.1200008392334}, "radius": 0.5, "color": "#dddddd", "alpha": 0.75});
# 	viewer_17871167741321266.addSphere({"center": {"x": -16.059999465942383, "y": 16.74799919128418, "z": -20.660999298095703}, "radius": 0.5, "color": "#dddddd", "alpha": 0.75});
# 	viewer_17871167741321266.addSphere({"center": {"x": -16.392000198364258, "y": 15.770999908447266, "z": -20.783000946044922}, "radius": 0.5, "color": "#dddddd", "alpha": 0.75});
# 	viewer_17871167741321266.addSphere({"center": {"x": -15.88599967956543, "y": 14.767000198364258, "z": -20.969999313354492}, "radius": 0.5, "color": "#dddddd", "alpha": 0.75});
# 	viewer_17871167741321266.addSphere({"center": {"x": -15.059000015258789, "y": 15.105999946594238, "z": -21.65399932861328}, "radius": 0.5, "color": "#dddddd", "alpha": 0.75});
# 	viewer_17871167741321266.addSphere({"center": {"x": -14.800999641418457, "y": 15.954999923706055, "z": -21.333999633789062}, "radius": 0.5, "color": "#dddddd", "alpha": 0.75});
# 	viewer_17871167741321266.addSphere({"center": {"x": -14.310999870300293, "y": 16.104999542236328, "z": -22.224000930786133}, "radius": 0.5, "color": "#dddddd", "alpha": 0.75});
# 	viewer_17871167741321266.addSphere({"center": {"x": -14.562000274658203, "y": 16.496000289916992, "z": -23.167999267578125}, "radius": 0.5, "color": "#dddddd", "alpha": 0.75});
# 	viewer_17871167741321266.addSphere({"center": {"x": -15.163000106811523, "y": 17.191999435424805, "z": -23.597999572753906}, "radius": 0.5, "color": "#dddddd", "alpha": 0.75});
# 	viewer_17871167741321266.addSphere({"center": {"x": -14.656000137329102, "y": 17.41200065612793, "z": -24.270999908447266}, "radius": 0.5, "color": "#dddddd", "alpha": 0.75});
# 	viewer_17871167741321266.addSphere({"center": {"x": -14.692000389099121, "y": 18.315000534057617, "z": -23.72599983215332}, "radius": 0.5, "color": "#dddddd", "alpha": 0.75});
# 	viewer_17871167741321266.addSphere({"center": {"x": -14.369000434875488, "y": 19.138999938964844, "z": -23.759000778198242}, "radius": 0.5, "color": "#dddddd", "alpha": 0.75});
# 	viewer_17871167741321266.addSphere({"center": {"x": -15.130999565124512, "y": 19.750999450683594, "z": -24.062000274658203}, "radius": 0.5, "color": "#dddddd", "alpha": 0.75});
# 	viewer_17871167741321266.addSphere({"center": {"x": -14.0649995803833, "y": 19.865999221801758, "z": -24.43000030517578}, "radius": 0.5, "color": "#dddddd", "alpha": 0.75});
# 	viewer_17871167741321266.addSphere({"center": {"x": -14.288999557495117, "y": 19.086999893188477, "z": -25.149999618530273}, "radius": 0.5, "color": "#dddddd", "alpha": 0.75});
# 	viewer_17871167741321266.addSphere({"center": {"x": -14.128000259399414, "y": 19.67799949645996, "z": -25.965999603271484}, "radius": 0.5, "color": "#dddddd", "alpha": 0.75});
# 	viewer_17871167741321266.addSphere({"center": {"x": -14.255000114440918, "y": 19.93000030517578, "z": -27.049999237060547}, "radius": 0.5, "color": "#dddddd", "alpha": 0.75});
# 	viewer_17871167741321266.addSphere({"center": {"x": -13.640999794006348, "y": 20.75200080871582, "z": -27.17799949645996}, "radius": 0.5, "color": "#dddddd", "alpha": 0.75});
# 	viewer_17871167741321266.addSphere({"center": {"x": -13.12600040435791, "y": 21.53700065612793, "z": -26.93000030517578}, "radius": 0.5, "color": "#dddddd", "alpha": 0.75});
# 	viewer_17871167741321266.addSphere({"center": {"x": -12.456000328063965, "y": 22.290000915527344, "z": -26.768999099731445}, "radius": 0.5, "color": "#dddddd", "alpha": 0.75});
# 	viewer_17871167741321266.addSphere({"center": {"x": -12.052000045776367, "y": 21.58300018310547, "z": -26.038999557495117}, "radius": 0.5, "color": "#dddddd", "alpha": 0.75});
# 	viewer_17871167741321266.addSphere({"center": {"x": -12.428000450134277, "y": 21.610000610351562, "z": -25.136999130249023}, "radius": 0.5, "color": "#dddddd", "alpha": 0.75});
# 	viewer_17871167741321266.addSphere({"center": {"x": -13.213000297546387, "y": 21.111000061035156, "z": -24.68899917602539}, "radius": 0.5, "color": "#dddddd", "alpha": 0.75});
# 	viewer_17871167741321266.addSphere({"center": {"x": -13.692999839782715, "y": 21.295000076293945, "z": -25.472999572753906}, "radius": 0.5, "color": "#dddddd", "alpha": 0.75});
# 	viewer_17871167741321266.addSphere({"center": {"x": -13.894000053405762, "y": 22.09600067138672,
