# %% [markdown]
# # 3D polymer + loop extrusion
#
# Set up and run a polychrom/OpenMM simulation of a polymer with cohesin loop extrusion
# and CTCF boundaries. Work top to bottom: each cell defines one group of settings, the
# last few assemble them, run, and look at the output.
#
# The code lives in three modules next to this notebook:
#
# | file | what it does |
# | --- | --- |
# | `extrusion.py` | CTCF stall arrays and the 1D LEF translocator (no OpenMM needed) |
# | `sim3D.py` | `SimParams` + the polymer/force setup + the run loop |
# | `smcBondUpdater.py` | pushes LEF positions into OpenMM harmonic bonds each step |
#
# Compartments are **not** modelled. If you want type-specific interactions you give
# `monomer_types` and `interaction_matrix` directly (step 3) and they go straight to
# polychrom's `heteropolymer_SSW`; leave them as `None` for a plain homopolymer.

# %%
# %load_ext autoreload
# %autoreload 2

import os, sys
import numpy as np
import matplotlib.pyplot as plt

from polysim import extrusion, OUTPUTS
from polysim.sim3d import SimParams, run

# the first import compiles LEF_Dynamics.pyx via pyximport -- a few seconds, once
print("output goes to", OUTPUTS)
# Out:
# ready

# %% [markdown]
# ## 1. Polymer geometry
#
# `npoly` monomers split into `nchr` equal chains, or give `chr_sizes` explicitly for
# unequal chains (then `npoly` and `nchr` are derived from it and the values below are
# ignored). `density` is monomers per unit volume inside the spherical confinement.

# %%
NPOLY     = 10000        # total monomers
NCHR      = 1            # number of chains
CHR_SIZES = None         # e.g. [5000, 3000, 2000] to override NPOLY / NCHR
DENSITY   = 0.2          # monomers per unit volume

# %% [markdown]
# ## 2. CTCF sites
#
# Two lists of monomer indices, replacing the old `ctcf.dat` file:
#
# - `CTCF_LEFT` blocks the **left-moving** leg
# - `CTCF_RIGHT` blocks the **right-moving** leg
#
# so to hold a loop between monomers `a < b`, put `a` in `CTCF_LEFT` and `b` in `CTCF_RIGHT`.
#
# `extrusion.tile_sites(base, period, length)` repeats a pattern along the chain, which is
# what the old file format was for. For per-site strengths, pass a dict `{index: prob}`
# instead of a list and `STALL` is ignored for that list.

# %%
STALL      = 0.8         # stall probability per encounter (per arrival at the site)
STALL_ALL  = False       # True = stall everywhere; ignores the lists below

# a periodic array of loops: left boundary at 100, right boundary at 900, every 1000 monomers
CTCF_LEFT  = extrusion.tile_sites([100], period=1000, length=NPOLY)
CTCF_RIGHT = extrusion.tile_sites([900], period=1000, length=NPOLY)

# per-site strengths instead:
# CTCF_LEFT = {100: 0.95, 1100: 0.5, 2100: 0.8}

print(len(CTCF_LEFT), "left  sites:", CTCF_LEFT[:6], "...")
print(len(CTCF_RIGHT), "right sites:", CTCF_RIGHT[:6], "...")
# Out:
# 10 left  sites: [100, 1100, 2100, 3100, 4100, 5100] ...
# 10 right sites: [900, 1900, 2900, 3900, 4900, 5900] ...

# %% [markdown]
# ## 3. Monomer types and interactions (optional)
#
# Leave both `None` for a homopolymer with soft repulsion only — that is the default and
# what you want if you are not studying type-specific interactions.
#
# To switch them on, give `MONOMER_TYPES` (one integer per monomer, values `0..ntypes-1`)
# and a symmetric `INTERACTION_MATRIX` of attraction energies in kT. They must be given
# together.

# %%
MONOMER_TYPES      = None
INTERACTION_MATRIX = None

# Example: two types, where type-1 monomers attract each other at 0.5 kT
# MONOMER_TYPES = np.zeros(NPOLY, dtype=int)
# MONOMER_TYPES[2000:4000] = 1
# MONOMER_TYPES[6000:8000] = 1
# INTERACTION_MATRIX = np.array([[0.0, 0.0],
#                                [0.0, 0.5]])

# %% [markdown]
# ## 4. Assemble the parameters
#
# Everything below is a keyword argument of `SimParams` with a sensible default; the
# extrusion defaults follow Gabriele et al. 2022 and the integration defaults Goel et al.
# 2025. Anything you do not list keeps its default — see the reference cell at the bottom
# for the full list.
#
# `summary()` resolves the derived quantities (number of LEFs, confinement radius, block
# schedule) and raises early if the configuration is inconsistent, so run it before
# committing to a long job.

# %%
params = SimParams(
    # --- geometry (from step 1) ---
    npoly=NPOLY, nchr=NCHR, chr_sizes=CHR_SIZES, density=DENSITY,

    # --- CTCF (from step 2) ---
    ctcf_left=CTCF_LEFT, ctcf_right=CTCF_RIGHT, stall=STALL, stallall=STALL_ALL,

    # --- monomer types (from step 3) ---
    monomer_types=MONOMER_TYPES, interaction_matrix=INTERACTION_MATRIX,

    # --- loop extrusion ---
    life=3000,             # LEF lifetime, in LEF timesteps
    sep=480,               # monomers per LEF -> n_lefs = npoly // sep
    vlef=0.05,             # p(step per leg per timestep)
    lifebooststalled=4,    # lifetime multiplier while stalled at a CTCF

    # --- integration ---
    platform="CUDA", gpu="0",
    integrator="langevin", dt=40, thermostat=0.01, thermostat0=0.01,
    polysteps=450,         # polymer timesteps per LEF timestep

    # --- schedule ---
    numsave=10000,         # production blocks
    saveevery=100,         # LEF steps per block; must divide blocks_per_updater (1000)
    initskip=80,           # blocks of equilibration
    initsteps=1000000,     # LEF-only steps before the polymer starts moving

    # --- output ---
    outpath=OUTPUTS,     # polysim.OUTPUTS, outside the repository
    flag="",               # label appended to the auto-generated folder name
)

print(params.summary())
# Out:
# polymer      10000 monomers in 1 chain(s) [10000]
# confinement  sphere r=36.8 at density 0.2
# interactions homopolymer (soft repulsion, 3.0 kT)
# LEFs         20 (1 per 480 monomers), lifetime 3000, v=0.05/step
# CTCF         20 stall site(s), p=0.8 per encounter, lifetime x4 while stalled
# schedule     10080 blocks written (80 of them equilibration, drop those), 100 LEF steps each, 450 polymer steps per LEF step

# %% [markdown]
# ## 5. Run
#
# This writes to a fresh auto-named folder under `outpath` and returns its path. A
# production run is long — for a first smoke test shrink it drastically and use the CPU
# platform:
#
# ```python
# params = SimParams(npoly=2000, sep=400, life=100, numsave=2, saveevery=100,
#                    initskip=1, initsteps=1000, blocks_per_updater=100, polysteps=20,
#                    platform="CPU", ctcf_left=[100, 1100], ctcf_right=[900, 1900],
#                    outpath=OUTPUTS, flag="smoketest")
# ```

# %%
folder = run(params)
# Out:
# polymer      10000 monomers in 1 chain(s) [10000]
# confinement  sphere r=36.8 at density 0.2
# interactions homopolymer (soft repulsion, 3.0 kT)
# LEFs         20 (1 per 480 monomers), lifetime 3000, v=0.05/step
# CTCF         20 stall site(s), p=0.8 per encounter, lifetime x4 while stalled
# schedule     10080 blocks written (80 of them equilibration, drop those), 100 LEF steps each, 450 polymer steps per LEF step
#
# output -> outputs/trajectory0002_npoly10000_nchr1_dens0.2_life3000_sep480_vlef0.05_dt40_stallsites0.8_lifeboost4
# equilibrating LEF dynamics for 1000000 steps...
#   done in 0.4 s
# updater init 0 / 1008  (equilibration)
# INFO:root:Performing local energy minimization
# INFO:root:adding force spherical_confinement 0
# INFO:root:adding force harmonic_bonds 1
# INFO:root:adding force angle 2
# INFO:root:adding force polynomial_repulsive 3
# Exclude neighbouring chain particles from polynomial_repulsive
# Number of exceptions: 9999
# ...

# %% [markdown]
# ## 6. Look at the output
#
# The folder holds:
#
# | file | contents |
# | --- | --- |
# | `blocks_*.h5` | the trajectory, read with `polychrom.hdf5_format` |
# | `paramsDict.pkl` | the `SimParams` as a dict |
# | `sites.npz` | the per-monomer LEF arrays actually used (birth/death/stall/pause) |
# | `SMC*.dat`, `bondsAdded.txt` | LEF bond lists over time, if `save_smc_bonds` |
#
# Remember the first `n_equil_blocks` blocks are equilibration — drop them before analysis.

# %%
from polychrom.hdf5_format import list_URIs, load_URI
import polychrom.polymer_analyses as polymer_analyses

uris = list_URIs(folder)
n_equil = params.schedule()["n_equil_blocks"]
print("{0} blocks written, dropping the first {1} (equilibration)".format(len(uris), n_equil))

production = uris[n_equil:]
last = load_URI(production[-1])["pos"]
print("last conformation:", last.shape)

# %%
# radius of gyration over the production blocks, and the final conformation
rg = [np.sqrt(polymer_analyses.Rg2(load_URI(u)["pos"])) for u in production]

fig = plt.figure(figsize=(11, 4.5))

ax = fig.add_subplot(1, 2, 1)
ax.plot(rg, lw=1)
ax.set_xlabel("production block")
ax.set_ylabel("radius of gyration")
ax.set_title("equilibration check")

ax = fig.add_subplot(1, 2, 2, projection="3d")
for start, end, _ in params.chains:
    ax.plot(*last[start:end].T, lw=0.4)
ax.set_title("final conformation")
ax.set_axis_off()

plt.tight_layout()
plt.show()

# %%
# the LEF arrays that were actually used -- a good sanity check on the CTCF setup
sites = np.load(os.path.join(folder, "sites.npz"))

fig, ax = plt.subplots(2, 1, figsize=(11, 4), sharex=True)
ax[0].plot(sites["stallLeft"], lw=0.8, label="stallLeft")
ax[0].plot(-sites["stallRight"], lw=0.8, label="-stallRight")
ax[0].set_ylabel("stall prob")
ax[0].legend(loc="upper right", fontsize=8)

ax[1].plot(1.0 / sites["stallDeath"], lw=0.8, label="lifetime while stalled")
ax[1].plot(1.0 / sites["death"], lw=0.8, ls="--", label="lifetime while moving")
ax[1].set_xlabel("monomer")
ax[1].set_ylabel("LEF lifetime")
ax[1].legend(loc="upper right", fontsize=8)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Reference: every parameter
#
# `SimParams` is a dataclass, so this lists every field with its current value. The
# inline comments in `sim3D.py` explain each one.

# %%
from dataclasses import fields

for f in fields(SimParams):
    value = getattr(params, f.name)
    if isinstance(value, (list, np.ndarray)) and len(value) > 6:
        value = "{0} of length {1}".format(type(value).__name__, len(value))
    print("{0:22s} {1}".format(f.name, value))
